# %%
import torch
import numpy as np
from torch.optim.optimizer import Optimizer

# %%
class ExactProximalWithSegmentSearch(Optimizer):

    """
    Algorithm 2.7
    """
    
    def __init__(self, params, f, p, H, sprox):
        
        """Implements pth-order proximal-point methods with exact search.
        
        Assuming E as finite-dimensional real vector space.
        
        Arguments:
            f (function(E) -> float)
            p (int) order of operator
            H (float) const > 0
            sprox (function(E, E, int, float) -> (E, float)) the pth-order proximal-point operators.
        """
        if not p > 0 or not type(p) == int:
            raise ValueError('p should be positive integer')
            
        if not H > 0:
            raise ValueError('H should be positive')
            
        params = list(params)
        psiargmin = []
            
        for param in params:
            psiargmin.append(param.clone().detach())
            
        defaults = dict(
            f = f,
            p = p,
            H = H,
            A = 0,
            psiargmin = psiargmin,
            sprox = sprox
        )
        
        super(ExactProximalWithSegmentSearch, self).__init__(params, defaults)
        
    def step(self):
        """ Performs a single optimization step. """
        
        for group in self.param_groups:
            f = group['f']
            p = group['p']
            H = group['H']
            A = group['A']
            psiargmin = group['psiargmin']
            sprox = group['sprox']
            x = group['params']
            
            v = psiargmin
            u = np.array(v) - np.array(x)
            x_, t = sprox(x, list(u), p, H)
            y = f(x)
            y.backward()
            g = torch.tensor(0.0)
            
            for xi in x:
                g.add_(torch.mul(xi.grad, xi.grad))
                
            g.sqrt_().pow_((1 - p)/p).mul_(torch.pow(torch.tensor(1/H), torch.tensor(1/p)))
            g = g.cpu().detach().numpy()[0]
            a = 0.5 * (g + np.sqrt(g * g + 4 * g * A))
            A += a
            
            for i, xi in enumerate(x):                                                 
                psi[i].add_(torch.mul(torch.tensor(a), xi.grad))

# %% [markdown]
# Let's generate some data...

# %%
np.random.seed(42)
K = 200
T = 160
x = np.random.rand(K, 1)
y = 2 * x + 1 + .1 * np.random.randn(K, 1)

idx = np.arange(K)
np.random.shuffle(idx)

train_idx = idx[:T]
test_idx = idx[T:]

x_train, y_train = x[train_idx], y[train_idx]
x_test, y_test = x[test_idx], y[test_idx]

# %% [markdown]
# ...and visialize it:

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 10)
y = 2 * x + 1
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13,6))
ax1.scatter(x_train, y_train)
ax1.plot(x, y, color='black', label='kek')
ax1.set_title('Train')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax2.scatter(x_test, y_test, color='red')
ax2.plot(x, y, color='black')
ax2.set_title('Test')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
plt.show()

# %% [markdown]
# Migrate from numpy arrays to tensors:

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
x_train_tensor = torch.from_numpy(x_train).float().to(device)
y_train_tensor = torch.from_numpy(y_train).float().to(device)
x_test_tensor = torch.from_numpy(x_test).float().to(device)
y_test_tensor = torch.from_numpy(y_test).float().to(device)

# %% [markdown]
# Our model will be linear regression:

# %%
class LinearRegression(torch.nn.Module):
    
    def __init__(self, n_params):
        super().__init__()
        self.linear = torch.nn.Linear(n_params, 1)
    
    # predict
    def forward(self, x):
        return self.linear(x)

# %%
torch.manual_seed(42)
lr = 0.1
n_epochs = 1000

model = LinearRegression(1).to(device)

loss_fn = torch.nn.MSELoss(reduction='mean')
#optimizer = torch.optim.SGD(model.parameters(), lr=lr) # change to our optimizer

optimizer = ExactProximalWithSegmentSearch(
    model.parameters(),
    f=lambda x: loss_fn(y_train_tensor, model.linear(x_train_tensor)),
    p=2,
    H=1.0,
    sprox=lambda x, u, p, H: ([0.0, 0.0], 0.0)
)

for epoch in range(n_epochs):
    model.train()
    predicted = model(x_train_tensor)
    loss = loss_fn(y_train_tensor, predicted)
    loss.backward()
    optimizer.step()
    optimizer.zero_grad()

model.state_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-f093528d7a02> in <module>
#      21     loss = loss_fn(y_train_tensor, predicted)
#      22     loss.backward()
# ---> 23     optimizer.step()
#      24     optimizer.zero_grad()
#      25
#
# <ipython-input-37-60c8bccd6ec2> in step(self)
#      60
#      61             for xi in x:
# ---> 62                 g.add_(torch.mul(xi.grad, xi.grad))
#      63
#      64             g.sqrt_().pow_((1 - p)/p).mul_(torch.pow(torch.tensor(1/H), torch.tensor(1/p)))
#
# AttributeError: 'float' object has no attribute 'grad'

# %% [markdown]
# As we can see, all is OK: weight is ~2, bias is ~1
